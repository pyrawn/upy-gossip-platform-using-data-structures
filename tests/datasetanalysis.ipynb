# %%
import pandas as pd

# %%
df_posts= pd.read_csv('../assets/data/posts.csv')

# %%
df_posts
# Out:
#    post_id                                          post_text  author_id  \
# 0        1                                Angelo best brawler          4
# 1        2                              t amo juan carlos uwu          5
# 2        3                                     Totally agree!          6
# 3        4                                    Haha, nice one!          7
# 4        5  A veces pienso que estructuras de datos es la ...          4
# 5        6                                             Holaaa          4
# 6        7                                                Lol          4
# 7        8                                            Se sabe          4
# 8        9                               Tipico de main edgar          4
#
#    parent_id        date
# 0        NaN  2024-11-20
# 1        NaN  2024-11-20
# 2        1.0  2024-11-21
# 3        3.0  2024-11-22
# 4        NaN  2024-11-26
# 5        NaN  2024-11-26
# 6        NaN  2024-11-26
# 7        2.0  2024-11-26
# ...

# %%
df_users = pd.read_csv('../assets/data/users.csv')

# %%
df_users
# Out:
#    id  username     password                description
# 0   1     user1  password123                        NaN
# 1   2     user2  password456                        NaN
# 2   3     user3  password789                        NaN
# 3   4    pyrawn   angelonian    Angelonians, taituwande
# 4   5      this    mainfrank  Melodian, taituwande, ah!
# 5   6   valeria     lorena22                #TeamUNACAR
# 6   7    lorena     3012105@                         :p
# 7   8   elprofe       sara21       Haciendo mi tesis...
# 8   9  elisabet    chicle123                Its yubarta
# 9  10  new_user          ABC                       LMAO
